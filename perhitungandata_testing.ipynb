# %% [markdown]
# <a href="https://colab.research.google.com/github/Puritiwi/Algoritmapemrograman/blob/main/perhitungandata_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

train = pd.read_excel('data training.xlsx', names=['No', 'Tanggal Penerimaan Surat', 'surat masuk', 'Selisih Hari', 'Hal', 'Jenis Surat'], header=0)
test = pd.read_excel('perhitungan testing.xlsx', names=['No', 'Tanggal Penerimaan Surat', 'surat masuk', 'Selisih Hari', 'Hal', 'Jenis Surat'], header=0)

# %%
train = pd.read_excel('data training.xlsx')

# %%
test = pd.read_excel('perhitungan testing.xlsx')

# %%
print(train.columns)
print(test.columns)
# Out:
# Index(['No', 'Tanggal Penerimaan Surat', 'surat masuk', 'Selisih Hari', 'Hal',
#        'Jenis Surat'],
#       dtype='object')
# Index(['No', 'Tanggal Penerimaan Surat', 'surat masuk', 'Selisih Hari', 'Hal',
#        'Jenis Surat'],
#       dtype='object')

# %%
X_train = train[['Selisih Hari']]
y_train = train['Jenis Surat']

X_test = test[['Selisih Hari']]

# %%
k = 3
knn = KNeighborsClassifier(n_neighbors=k)

# %%
print(X_train.head())
print(y_train.head())
# Out:
#    Selisih Hari
# 0  Selisih Hari
# 1             0
# 2            86
# 3             0
# 4            61
# 0           NaN
# 1      undangan
# 2      undangan
# 3      undangan
# 4    permohonan
# Name: Jenis Surat, dtype: object

# %%
# Misal untuk train
train = train[train['Selisih Hari'] != 'Selisih Hari']
train = train.dropna(subset=['Selisih Hari', 'Jenis Surat'])

# %%
train['Selisih Hari'] = pd.to_numeric(train['Selisih Hari'])

# %%
print(train.head())
print(train.dtypes)
# Out:
#     No Tanggal Penerimaan Surat          surat masuk  Selisih Hari  \
# 1  1.0               2025-09-15  2025-09-15 00:00:00             0
# 2  2.0               2025-09-14  2025-12-09 00:00:00            86
# 3  3.0               2025-08-26  2025-08-26 00:00:00             0
# 4  4.0               2025-08-01  2025-06-01 00:00:00            61
# 5  5.0               2025-04-23  2025-04-23 00:00:00             0
#
#                                           Hal Jenis Surat
# 1  undangan kegiatan single country training     undangan
# 2                undangan briefing pendataan     undangan
# 3   undangan pengumpulan data siswa pesantren    undangan
# 4         permohonan administrasi kepegawaian  permohonan
# 5                           undangan briefing    undangan
# No                                 float64
# Tanggal Penerimaan Surat    datetime64[ns]
# surat masuk                         object
# Selisih Hari                         int64
# ...

# %%
# Hapus baris yang salah / header duplikat
train = train[train['Selisih Hari'] != 'Selisih Hari'].dropna(subset=['Selisih Hari', 'Jenis Surat'])
train['Selisih Hari'] = pd.to_numeric(train['Selisih Hari'])

# %%
X_train = train[['Selisih Hari']]
y_train = train['Jenis Surat']

# %%
test = test[test['Selisih Hari'] != 'Selisih Hari'].dropna(subset=['Selisih Hari'])
test['Selisih Hari'] = pd.to_numeric(test['Selisih Hari'])
X_test = test[['Selisih Hari']]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)   # <- ini wajib sebelum predict
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test['Jenis Surat Prediksi'] = knn.predict(X_test)
print(test[['Selisih Hari', 'Jenis Surat Prediksi']])
# Out:
#     Selisih Hari Jenis Surat Prediksi
# 1              0             undangan
# 2             31             undangan
# 3              0             undangan
# 4              0             undangan
# 5              0             undangan
# 6              0             undangan
# 7              0             undangan
# 8              0             undangan
# 9            204             undangan
# 10            30             undangan
# 11           122             undangan
# 12             2             undangan
# 13           232             undangan
# 14             0             undangan
# 15             0             undangan
# 16             1             undangan
# 17             0             undangan
# 18             3             undangan
# 19             0             undangan
# 20             1             undangan
# 21             0             undangan
# 22             0             undangan
# 23             2             undangan
# 24             2             undangan
# ...
